# %%
import aqml.cheminfo.oechem.amon as caa

# %%
target = ["CC1(C(N2C(S1)C(C2=O)NC(=O)CC3=CC=CC=C3)C(=O)O)C"]

# %%
obj = caa.ParentMols(target, k=10, i3d=False, label='label')
# Out:
# #Mid 1 CC1(C(N2C(S1)C(C2=O)NC(=O)CC3=CC=CC=C3)C(=O)O)C
#  ## can =  C
#     \To be accepted/
#  ## can =  C
#  ## can =  C
#  ## can =  N
#     \To be accepted/
#  ## can =  C
#  ## can =  S
#     \To be accepted/
#  ## can =  C
#  ** [warning] **
#       Not all dvs==0 for the subg found, check!
#       This may happen when input is rad, but from which
#       it is still possible to extract non-rad amons
#       Example: c1(ccc(cc1)[C](C#N)C#N)[C](C#N)C#N
#              |
#  ## can =  N
#  ## can =  C
#  ## can =  O
#     \To be accepted/
#  ## can =  C
#
#
#  ## can =  CC
#     \To be accepted/
#
#
#  ## can =  CC
#
#
#  ## can =  CS
#     \To be accepted/
#
#
#  ## can =  CC
#
#
#  ## can =  CN
#     \To be accepted/
#
#
#  ## can =  CN
#
#
#  ## can =  CS
#
#
#  ## can =  CC
#
#
#  ## can =  CN
#
#
#  ## can =  C=O
#     \To be accepted/
#
#
#  ## can =  C=O
#
#
#  ## can =  C=C
#     \To be accepted/
#
#
#  ## can =  C=C
#
#
#  ## can =  C=C
#
#
#  ## can =  C=C
#
#
#  ## can =  C=C
#
#
#  ## can =  C=C
#
#
#  ## can =  C=O
#
#
#  ## can =  C(=O)O
#     \To be accepted/
#
#
#  ## can =  C=CC=C
#     \To be accepted/
#
#
#  ## can =  C=CC=C
#     \To be accepted/
#
#
#  ## can =  C=CC=C
#     \To be accepted/
#
#
#  ## can =  C=CC=C
#     \To be accepted/
#
#
#  ## can =  c1ccccc1
#     \To be accepted/
#  ## can =  c1ccccc1
#     \To be accepted/
#
#
#  ## can =  C=CC=C
#     \To be accepted/
#
#
#  ## can =  C=CC=C
#     \To be accepted/
#
#
#  ## can =  CC=C
#     \To be accepted/
#
#
#  ## can =  CC=C
#     \To be accepted/
#
#
#  ## can =  CC(=C)C=C
#     \To be accepted/
#
#
#  ## can =  CC(=C)C=C
#     \To be accepted/
#
#
#  ## can =  Cc1ccccc1
#     \To be accepted/
#  ## can =  Cc1ccccc1
#     \To be accepted/
#
#
#  ## can =  CC=CC=C
#     \To be accepted/
#
#
#  ## can =  CC=CC=C
#     \To be accepted/
#
#
#  ## can =  CC=O
#     \To be accepted/
#
#
#  ## can =  C=CCC=O
#     \To be accepted/
#
#
#  ## can =  C=CCC=O
#     \To be accepted/
#
#
#  ## can =  C=CC(=C)CC=O
#     \To be accepted/
#
#
#  ## can =  C=CC(=C)CC=O
#     \To be accepted/
#
#
#  ## can =  c1ccc(cc1)CC=O
#     \To be accepted/
#  ## can =  c1ccc(cc1)CC=O
#     \To be accepted/
#
#
#  ## can =  C=CC=CCC=O
#     \To be accepted/
#
#
#  ## can =  C=CC=CCC=O
#     \To be accepted/
#
#
#  ## can =  C(=O)N
#     \To be accepted/
#
#
#  ## can =  CC(=O)N
#     \To be accepted/
#
#
#  ## can =  C=CCC(=O)N
#     \To be accepted/
#
#
#  ## can =  C=CCC(=O)N
#     \To be accepted/
#
#
#  ## can =  C=CC(=C)CC(=O)N
#     \To be accepted/
#
#
#  ## can =  C=CC(=C)CC(=O)N
#     \To be accepted/
#
#
#  ## can =  c1ccc(cc1)CC(=O)N
#     \To be accepted/
#  ## can =  c1ccc(cc1)CC(=O)N
#     \To be accepted/
#
#
#  ## can =  C=CC=CCC(=O)N
#     \To be accepted/
#
#
#  ## can =  C=CC=CCC(=O)N
#     \To be accepted/
#
#
#  ## can =  CNC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)NC
#     \To be accepted/
#
#
#  ## can =  CNC(=O)CC=C
#     \To be accepted/
#
#
#  ## can =  CNC(=O)CC=C
#     \To be accepted/
#
#
#  ## can =  CNC(=O)CC(=C)C=C
#     \To be accepted/
#
#
#  ## can =  CNC(=O)CC(=C)C=C
#     \To be accepted/
#
#
#  ## can =  CNC(=O)CC=CC=C
#     \To be accepted/
#
#
#  ## can =  CNC(=O)CC=CC=C
#     \To be accepted/
#
#
#  ## can =  CC=O
#     \To be accepted/
#
#
#  ## can =  C(C=O)N
#     \To be accepted/
#
#
#  ## can =  C(C=O)NC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)NCC=O
#     \To be accepted/
#
#
#  ## can =  C=CCC(=O)NCC=O
#     \To be accepted/
#
#
#  ## can =  C=CCC(=O)NCC=O
#     \To be accepted/
#
#
#  ## can =  CCN
#     \To be accepted/
#
#
#  ## can =  CC(C=O)N
#     \To be accepted/
#
#
#  ## can =  CC(C=O)NC=O
#     \To be accepted/
#
#
#  ## can =  CC(C=O)NC(=O)C
#     \To be accepted/
#
#
#  ## can =  CC(C=O)NC(=O)CC=C
#     \To be accepted/
#
#
#  ## can =  CC(C=O)NC(=O)CC=C
#     \To be accepted/
#
#
#  ## can =  CCNC=O
#     \To be accepted/
#
#
#  ## can =  CCNC(=O)C
#     \To be accepted/
#
#
#  ## can =  CCNC(=O)CC=C
#     \To be accepted/
#
#
#  ## can =  CCNC(=O)CC=C
#     \To be accepted/
#
#
#  ## can =  CCNC(=O)CC(=C)C=C
#     \To be accepted/
#
#
#  ## can =  CCNC(=O)CC(=C)C=C
#     \To be accepted/
#
#
#  ## can =  CCNC(=O)CC=CC=C
#     \To be accepted/
#
#
#  ## can =  CCNC(=O)CC=CC=C
#     \To be accepted/
#
#
#  ## can =  CCC=O
#     \To be accepted/
#
#
#  ## can =  CCS
#     \To be accepted/
#
#
#  ## can =  C(CS)N
#     \To be accepted/
#
#
#  ## can =  C(C(C=O)N)S
#     \To be accepted/
#
#
#  ## can =  C(C(C=O)NC=O)S
#     \To be accepted/
#
#
#  ## can =  CC(=O)NC(CS)C=O
#     \To be accepted/
#
#
#  ## can =  C(CS)NC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)NCCS
#     \To be accepted/
#
#
#  ## can =  C=CCC(=O)NCCS
#     \To be accepted/
#
#
#  ## can =  C=CCC(=O)NCCS
#     \To be accepted/
#
#
#  ## can =  C(CS)C=O
#     \To be accepted/
#
#
#  ## can =  C(=O)N
#     \To be accepted/
#
#
#  ## can =  CC(=O)N
#     \To be accepted/
#
#
#  ## can =  C(C(=O)N)N
#     \To be accepted/
#
#
#  ## can =  C(C(=O)N)NC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)NCC(=O)N
#     \To be accepted/
#
#
#  ## can =  C=CCC(=O)NCC(=O)N
#     \To be accepted/
#
#
#  ## can =  C=CCC(=O)NCC(=O)N
#     \To be accepted/
#
#
#  ## can =  C(N)S
#     \To be accepted/
#
#
#  ## can =  CCN
#     \To be accepted/
#
#
#  ## can =  CC(N)S
#     \To be accepted/
#
#
#  ## can =  C1C(NC1=O)S
#     \To be accepted/
#
#
#  ## can =  C1(C(NC1=O)S)N
#     \To be accepted/
#
#
#  ## can =  C(=O)NC1C(NC1=O)S
#     \To be accepted/
#
#
#  ## can =  CC(=O)NC1C(NC1=O)S
#     \To be accepted/
#
#
#  ## can =  C(C(N)S)N
#     \To be accepted/
#
#
#  ## can =  C(C(N)S)NC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)NCC(N)S
#     \To be accepted/
#
#
#  ## can =  C=CCC(=O)NCC(N)S
#     \To be accepted/
#
#
#  ## can =  C=CCC(=O)NCC(N)S
#     \To be accepted/
#
#
#  ## can =  C1CNC1=O
#     \To be accepted/
#
#
#  ## can =  C1C(C(=O)N1)N
#     \To be accepted/
#
#
#  ## can =  C1C(C(=O)N1)NC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)NC1CNC1=O
#     \To be accepted/
#
#
#  ## can =  C(CN)N
#     \To be accepted/
#
#
#  ## can =  C(CNC=O)N
#     \To be accepted/
#
#
#  ## can =  CC(=O)NCCN
#     \To be accepted/
#
#
#  ## can =  C=CCC(=O)NCCN
#     \To be accepted/
#
#
#  ## can =  C=CCC(=O)NCCN
#     \To be accepted/
#
#
#  ## can =  C(NC=O)S
#     \To be accepted/
#
#
#  ## can =  CNC=O
#     \To be accepted/
#
#
#  ## can =  CC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)O
#     \To be accepted/
#
#
#  ## can =  CNC
#     \To be accepted/
#
#
#  ## can =  CN(CC=O)C=O
#     \To be accepted/
#
#
#  ## can =  CN(CC(=O)O)C=O
#     \To be accepted/
#
#
#  ## can =  C(C=O)N(CS)C=O
#     \To be accepted/
#
#
#  ## can =  C(C(=O)O)N(CS)C=O
#     \To be accepted/
#
#
#  ## can =  C1CN(C1=O)CC=O
#     \To be accepted/
#
#
#  ## can =  C1CN(C1=O)CC(=O)O
#     \To be accepted/
#
#
#  ## can =  C1C(N(C1=O)CC=O)S
#     \To be accepted/
#
#
#  ## can =  C1C(N(C1=O)CC(=O)O)S
#     \To be accepted/
#
#
#  ## can =  C(C=O)N1C(C(C1=O)N)S
#     \To be accepted/
#
#
#  ## can =  C1C(C(=O)N1CC(=O)O)N
#     \To be accepted/
#
#
#  ## can =  C1C(C(=O)N1CC=O)N
#     \To be accepted/
#
#
#  ## can =  CN(C)C=O
#     \To be accepted/
#
#
#  ## can =  CN(CS)C=O
#     \To be accepted/
#
#
#  ## can =  CN1CCC1=O
#     \To be accepted/
#
#
#  ## can =  CN1C(CC1=O)S
#     \To be accepted/
#
#
#  ## can =  CN1C(C(C1=O)N)S
#     \To be accepted/
#
#
#  ## can =  CN1C(C(C1=O)NC=O)S
#     \To be accepted/
#
#
#  ## can =  CN1CC(C1=O)N
#     \To be accepted/
#
#
#  ## can =  CN1CC(C1=O)NC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)NC1CN(C1=O)C
#     \To be accepted/
#
#
#  ## can =  C(C=O)NC=O
#     \To be accepted/
#
#
#  ## can =  C(C(=O)O)NC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)NCC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)NCC(=O)O
#     \To be accepted/
#
#
#  ## can =  C(C(=O)NCC(=O)O)N
#     \To be accepted/
#
#
#  ## can =  C(C=O)NC(=O)CN
#     \To be accepted/
#
#
#  ## can =  C(C=O)NC(=O)CNC=O
#     \To be accepted/
#
#
#  ## can =  CNC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)NC
#     \To be accepted/
#
#
#  ## can =  CNC(=O)CN
#     \To be accepted/
#
#
#  ## can =  CNC(=O)CNC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)NCC(=O)NC
#     \To be accepted/
#
#
#  ## can =  CNCC=O
#     \To be accepted/
#
#
#  ## can =  CNCC(=O)O
#     \To be accepted/
#
#
#  ## can =  C(C=O)NCS
#     \To be accepted/
#
#
#  ## can =  C(C(=O)O)NCS
#     \To be accepted/
#
#
#  ## can =  CCNCC=O
#     \To be accepted/
#
#
#  ## can =  CCNCC(=O)O
#     \To be accepted/
#
#
#  ## can =  CC(NCC=O)S
#     \To be accepted/
#
#
#  ## can =  CC(NCC(=O)O)S
#     \To be accepted/
#
#
#  ## can =  C(C(NCC(=O)O)S)N
#     \To be accepted/
#
#
#  ## can =  C(C=O)NC(CN)S
#     \To be accepted/
#
#
#  ## can =  C(C=O)NC(CNC=O)S
#     \To be accepted/
#
#
#  ## can =  C(CNCC(=O)O)N
#     \To be accepted/
#
#
#  ## can =  C(CNC=O)NCC(=O)O
#     \To be accepted/
#
#
#  ## can =  C(CNCC=O)N
#     \To be accepted/
#
#
#  ## can =  C(CNC=O)NCC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)NCCNCC=O
#     \To be accepted/
#
#
#  ## can =  CNCS
#     \To be accepted/
#
#
#  ## can =  CCNC
#     \To be accepted/
#
#
#  ## can =  CC(NC)S
#     \To be accepted/
#
#
#  ## can =  CNC(CN)S
#     \To be accepted/
#
#
#  ## can =  CNC(CNC=O)S
#     \To be accepted/
#
#
#  ## can =  CC(=O)NCC(NC)S
#     \To be accepted/
#
#
#  ## can =  CNCCN
#     \To be accepted/
#
#
#  ## can =  CNCCNC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)NCCNC
#     \To be accepted/
#
#
#  ## can =  CNCCNC(=O)CC=C
#     \To be accepted/
#
#
#  ## can =  CNCCNC(=O)CC=C
#     \To be accepted/
#
#
#  ## can =  C(C=O)N
#     \To be accepted/
#
#
#  ## can =  C(C(=O)O)N
#     \To be accepted/
#
#
#  ## can =  CCS
#     \To be accepted/
#
#
#  ## can =  CSC
#     \To be accepted/
#
#
#  ## can =  CCSC
#     \To be accepted/
#
#
#  ## can =  CCSCN
#     \To be accepted/
#
#
#  ## can =  CCSCC
#     \To be accepted/
#
#
#  ## can =  CCSC(C)N
#     \To be accepted/
#
#
#  ## can =  CCSC(CN)N
#     \To be accepted/
#
#
#  ## can =  CCSC1C(C(=O)N1)N
#     \To be accepted/
#
#
#  ## can =  CCSC(CNC=O)N
#     \To be accepted/
#
#
#  ## can =  CCSC(CNC(=O)C)N
#     \To be accepted/
#
#
#  ## can =  CCSC1CC(=O)N1
#     \To be accepted/
#
#
#  ## can =  CCSCCN
#     \To be accepted/
#
#
#  ## can =  CCSCC(C=O)N
#     \To be accepted/
#  ## can =  CCSCC(C=O)NC=O
#     \To be accepted/
#
#
#  ## can =  CCSCCNC=O
#     \To be accepted/
#
#
#  ## can =  CCSCCNC(=O)C
#     \To be accepted/
#
#
#  ## can =  CCSCCC=O
#     \To be accepted/
#
#
#  ## can =  CCSCNC=O
#     \To be accepted/
#
#
#  ## can =  CSCN
#     \To be accepted/
#
#
#  ## can =  CCSC
#     \To be accepted/
#
#
#  ## can =  CC(N)SC
#     \To be accepted/
#
#
#  ## can =  CSC(CN)N
#     \To be accepted/
#
#
#  ## can =  CSC1C(C(=O)N1)N
#     \To be accepted/
#
#
#  ## can =  CSC1C(C(=O)N1)NC=O
#     \To be accepted/
#
#
#  ## can =  CSC(CNC=O)N
#     \To be accepted/
#
#
#  ## can =  CC(=O)NCC(N)SC
#     \To be accepted/
#
#
#  ## can =  CSC1CC(=O)N1
#     \To be accepted/
#
#
#  ## can =  CSCCN
#     \To be accepted/
#
#
#  ## can =  CSCC(C=O)N
#     \To be accepted/
#
#
#  ## can =  CSCC(C=O)NC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)NC(CSC)C=O
#     \To be accepted/
#
#
#  ## can =  CSCCNC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)NCCSC
#     \To be accepted/
#
#
#  ## can =  CSCCNC(=O)CC=C
#     \To be accepted/
#
#
#  ## can =  CSCCNC(=O)CC=C
#     \To be accepted/
#
#
#  ## can =  CSCCC=O
#     \To be accepted/
#
#
#  ## can =  CSCNC=O
#     \To be accepted/
#
#
#  ## can =  CCS
#     \To be accepted/
#
#
#  ## can =  CCC
#     \To be accepted/
#
#
#  ## can =  CC(C)S
#     \To be accepted/
#
#
#  ## can =  CCN
#     \To be accepted/
#
#
#  ## can =  C(CS)N
#     \To be accepted/
#
#
#  ## can =  CCCN
#     \To be accepted/
#
#
#  ## can =  CC(CN)S
#     \To be accepted/
#
#
#  ## can =  CC(C(C=O)N)S
#     \To be accepted/
#
#
#  ## can =  CC(C(C(=O)O)N)S
#     \To be accepted/
#
#
#  ## can =  CC1C(NCS1)C=O
#     \To be accepted/
#
#
#  ## can =  CC1C(NCS1)C(=O)O
#     \To be accepted/
#
#
#  ## can =  CC1C(NC(S1)C)C(=O)O
#     \To be accepted/
#
#
#  ## can =  CC1C(N(CS1)C=O)C=O
#     # found 5-membered aromatic ring
#     \To be accepted/
#
#
#  ## can =  CC1C(NC(S1)C)C=O
#     \To be accepted/
#
#
#  ## can =  CC1C(NC(S1)CN)C=O
#     \To be accepted/
#
#
#  ## can =  CC(C(C(=O)O)NC=O)S
#     \To be accepted/
#
#
#  ## can =  CC(C(C=O)NC=O)S
#     \To be accepted/
#
#
#  ## can =  CC(C(C=O)NC(=O)C)S
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)N
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)NC
#     \To be accepted/
#
#
#  ## can =  CCC(C(=O)O)N
#     \To be accepted/
#
#
#  ## can =  CCC(C(=O)O)NC
#     \To be accepted/
#
#
#  ## can =  CCC(C(=O)O)N(C)C=O
#     \To be accepted/
#
#
#  ## can =  CCC(C(=O)O)NC=O
#     \To be accepted/
#
#
#  ## can =  CCC(C(=O)O)NC(=O)C
#     \To be accepted/
#
#
#  ## can =  CCC(C(=O)O)NCC
#     \To be accepted/
#
#
#  ## can =  CCC(C(=O)O)NCCN
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)N(C)C=O
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)N1CCC1=O
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)NC=O
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)NC(=O)C
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)NC(=O)CN
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)NCC
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)NCCN
#     \To be accepted/
#
#
#  ## can =  C(C(C=O)N)S
#     \To be accepted/
#
#
#  ## can =  C(C(C(=O)O)N)S
#     \To be accepted/
#
#
#  ## can =  C1C(NCS1)C=O
#     \To be accepted/
#
#
#  ## can =  C1C(NCS1)C(=O)O
#     \To be accepted/
#
#
#  ## can =  C1C(N(CS1)C=O)C(=O)O
#     # found 5-membered aromatic ring
#     \To be accepted/
#
#
#  ## can =  CC1NC(CS1)C(=O)O
#     \To be accepted/
#
#
#  ## can =  C1C(NC(S1)CN)C(=O)O
#     \To be accepted/
#
#
#  ## can =  C1C(N(CS1)C=O)C=O
#     # found 5-membered aromatic ring
#     \To be accepted/
#
#
#  ## can =  C1C2N(C1=O)C(CS2)C=O
#     # found 5-membered aromatic ring
#     \To be accepted/
#
#
#  ## can =  CC1NC(CS1)C=O
#     \To be accepted/
#
#
#  ## can =  C1C(NC(S1)CN)C=O
#     \To be accepted/
#
#
#  ## can =  C(C(C(=O)O)NC=O)S
#     \To be accepted/
#
#
#  ## can =  CC(=O)NC(CS)C(=O)O
#     \To be accepted/
#
#
#  ## can =  C(C(C=O)NC=O)S
#     \To be accepted/
#
#
#  ## can =  CC(=O)NC(CS)C=O
#     \To be accepted/
#
#
#  ## can =  C(C(C=O)NC(=O)CN)S
#     \To be accepted/
#
#
#  ## can =  CC(C=O)N
#     \To be accepted/
#
#
#  ## can =  CC(C=O)NC
#     \To be accepted/
#
#
#  ## can =  CC(C(=O)O)N
#     \To be accepted/
#
#
#  ## can =  CC(C(=O)O)NC
#     \To be accepted/
#
#
#  ## can =  CC(C(=O)O)N(C)C=O
#     \To be accepted/
#
#
#  ## can =  CC(C(=O)O)N1CCC1=O
#     \To be accepted/
#
#
#  ## can =  CC(C(=O)O)NC=O
#     \To be accepted/
#
#
#  ## can =  CC(C(=O)O)NC(=O)C
#     \To be accepted/
#
#
#  ## can =  CC(C(=O)O)NC(=O)CN
#     \To be accepted/
#
#
#  ## can =  CCNC(C)C(=O)O
#     \To be accepted/
#
#
#  ## can =  CC(C(=O)O)NCCN
#     \To be accepted/
#
#
#  ## can =  CC(C=O)N(C)C=O
#     \To be accepted/
#
#
#  ## can =  CC(C=O)N1CCC1=O
#     \To be accepted/
#
#
#  ## can =  CC(C=O)N1CC(C1=O)N
#     \To be accepted/
#
#
#  ## can =  CC(C=O)NC=O
#     \To be accepted/
#
#
#  ## can =  CC(C=O)NC(=O)C
#     \To be accepted/
#
#
#  ## can =  CC(C=O)NC(=O)CN
#     \To be accepted/
#
#
#  ## can =  CCNC(C)C=O
#     \To be accepted/
#
#
#  ## can =  CC(C=O)NCCN
#     \To be accepted/
#
#
#  ## can =  CC(C=O)NCCNC=O
#     \To be accepted/
#
#
#  ## can =  CC(CC=O)S
#     \To be accepted/
#
#
#  ## can =  CC(CC(=O)O)S
#     \To be accepted/
#
#
#  ## can =  CC(CC=O)SC
#     \To be accepted/
#
#
#  ## can =  CC(CC(=O)O)SC
#     \To be accepted/
#
#
#  ## can =  CCSC(C)CC(=O)O
#     \To be accepted/
#
#
#  ## can =  CC(CC(=O)O)SCCN
#     \To be accepted/
#
#
#  ## can =  CCSC(C)CC=O
#     \To be accepted/
#
#
#  ## can =  CC(CC=O)SCCN
#     \To be accepted/
#
#
#  ## can =  CC(CC=O)SCCC=O
#     \To be accepted/
#
#
#  ## can =  CCCC=O
#     \To be accepted/
#
#
#  ## can =  CCCC(=O)O
#     \To be accepted/
#
#
#  ## can =  C(CS)C=O
#     \To be accepted/
#
#
#  ## can =  C(CS)C(=O)O
#     \To be accepted/
#
#
#  ## can =  CSCCC=O
#     \To be accepted/
#
#
#  ## can =  CSCCC(=O)O
#     \To be accepted/
#
#
#  ## can =  CCSCCC(=O)O
#     \To be accepted/
#
#
#  ## can =  C(CSCCN)C(=O)O
#     \To be accepted/
#
#
#  ## can =  C(CSCCC(=O)O)C=O
#     \To be accepted/
#
#
#  ## can =  CCSCCC=O
#     \To be accepted/
#
#
#  ## can =  C(CSCCN)C=O
#     \To be accepted/
#
#
#  ## can =  C(CSCC(C=O)N)C=O
#     \To be accepted/
#
#
#  ## can =  C(CSCCNC=O)C=O
#     \To be accepted/
#
#
#  ## can =  C(CSCCC=O)C=O
#     \To be accepted/
#
#
#  ## can =  CCC=O
#     \To be accepted/
#
#
#  ## can =  CCC(=O)O
#     \To be accepted/
#
#
#  ## can =  CC1CNCS1
#     \To be accepted/
#
#
#  ## can =  CC1CN(CS1)C=O
#     # found 5-membered aromatic ring
#     \To be accepted/
#
#
#  ## can =  CC1CN2C(S1)CC2=O
#     # found 5-membered aromatic ring
#     \To be accepted/
#
#
#  ## can =  CC1CN2C(S1)C(C2=O)N
#     # found 5-membered aromatic ring
#     \To be accepted/
#
#
#  ## can =  CC1CNC(S1)C
#     \To be accepted/
#
#
#  ## can =  CC1CNC(S1)CN
#     \To be accepted/
#
#
#  ## can =  CC1CNC(S1)CNC=O
#     \To be accepted/
#
#
#  ## can =  CC(CNC=O)S
#     \To be accepted/
#
#
#  ## can =  CC(CNC(=O)C)S
#     \To be accepted/
#
#
#  ## can =  CC(CNC(=O)CN)S
#     \To be accepted/
#
#
#  ## can =  CCCNC
#     \To be accepted/
#
#
#  ## can =  CCCN(C)C=O
#     \To be accepted/
#
#
#  ## can =  CCCN1CCC1=O
#     \To be accepted/
#
#
#  ## can =  CCCN1CC(C1=O)N
#     \To be accepted/
#
#
#  ## can =  CCCNC=O
#     \To be accepted/
#
#
#  ## can =  CCCNC(=O)C
#     \To be accepted/
#
#
#  ## can =  CCCNC(=O)CN
#     \To be accepted/
#
#
#  ## can =  CCCNC(=O)CNC=O
#     \To be accepted/
#
#
#  ## can =  CCCNCC
#     \To be accepted/
#
#
#  ## can =  CCCNCCN
#     \To be accepted/
#
#
#  ## can =  CCCNCCNC=O
#     \To be accepted/
#
#
#  ## can =  CCCNCCNC(=O)C
#     \To be accepted/
#
#
#  ## can =  C1CSCN1
#     \To be accepted/
#
#
#  ## can =  C1CSCN1C=O
#     # found 5-membered aromatic ring
#     \To be accepted/
#
#
#  ## can =  C1CSC2N1C(=O)C2
#     # found 5-membered aromatic ring
#     \To be accepted/
#
#
#  ## can =  C1CSC2N1C(=O)C2N
#     # found 5-membered aromatic ring
#     \To be accepted/
#
#
#  ## can =  CC1NCCS1
#     \To be accepted/
#
#
#  ## can =  C1CSC(N1)CN
#     \To be accepted/
#
#
#  ## can =  C1CSC(N1)CNC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)NCC1NCCS1
#     \To be accepted/
#
#
#  ## can =  C(CS)NC=O
#     \To be accepted/
#
#
#  ## can =  CC(=O)NCCS
#     \To be accepted/
#
#
#  ## can =  C(CS)NC(=O)CN
#     \To be accepted/
#
#
#  ## can =  C(CS)NC(=O)CNC=O
#     \To be accepted/
#
#
#  ## can =  CCNC
#     \To be accepted/
#
#
#  ## can =  CCN(C)C=O
#     \To be accepted/
#
#
#  ## can =  CCN1CCC1=O
#     \To be accepted/
#
#
#  ## can =  CCN1CC(C1=O)N
#     \To be accepted/
#
#
#  ## can =  CCN1CC(C1=O)NC=O
#     \To be accepted/
#
#
#  ## can =  CCNC=O
#     \To be accepted/
#
#
#  ## can =  CCNC(=O)C
#     \To be accepted/
#
#
#  ## can =  CCNC(=O)CN
#     \To be accepted/
#
#
#  ## can =  CCNC(=O)CNC=O
#     \To be accepted/
#
#
#  ## can =  CCNC(=O)CNC(=O)C
#     \To be accepted/
#
#
#  ## can =  CCNCC
#     \To be accepted/
#
#
#  ## can =  CCNCCN
#     \To be accepted/
#
#
#  ## can =  CCNCCNC=O
#     \To be accepted/
#
#
#  ## can =  CCNCCNC(=O)C
#     \To be accepted/
#
#
#  ## can =  CC(C)SC
#     \To be accepted/
#
#
#  ## can =  CCSC(C)C
#     \To be accepted/
#
#
#  ## can =  CC(C)SCCN
#     \To be accepted/
#
#
#  ## can =  CC(C)SCC(C=O)N
#     \To be accepted/
#
#
#  ## can =  CC(C)SCCNC=O
#     \To be accepted/
#
#
#  ## can =  CC(C)SCCNC(=O)C
#     \To be accepted/
#
#
#  ## can =  CC(C)SCCC=O
#     \To be accepted/
#
#
#  ## can =  CCSC
#     \To be accepted/
#
#
#  ## can =  CCSCC
#     \To be accepted/
#
#
#  ## can =  CCSCCN
#     \To be accepted/
#
#
#  ## can =  CCSCC(C=O)N
#     \To be accepted/
#
#
#  ## can =  CCSCC(C=O)NC=O
#     \To be accepted/
#
#
#  ## can =  CCSCCNC=O
#     \To be accepted/
#
#
#  ## can =  CCSCCNC(=O)C
#     \To be accepted/
#
#
#  ## can =  CCSCCC=O
#     \To be accepted/
#
#
#  ## can =  CCC
#     \To be accepted/
#
#
#  ## can =  CCS
#     \To be accepted/
#
#
#  ## can =  CC(C)S
#     \To be accepted/
#
#
#  ## can =  CCC
#     \To be accepted/
#
#
#  ## can =  CC(C)C
#     \To be accepted/
#
#
#  ## can =  CC(C)S
#     \To be accepted/
#
#
#  ## can =  CC(C)(C)S
#     \To be accepted/
#
#
#  ## can =  CC(C)(CN)S
#     \To be accepted/
#
#
#  ## can =  CC(C)(C)SC
#     \To be accepted/
#
#
#  ## can =  CC1(C(NCS1)C=O)C
#     \To be accepted/
#
#
#  ## can =  CC1(C(NCS1)C(=O)O)C
#     \To be accepted/
#
#
#  ## can =  CC1NC(C(S1)(C)C)C=O
#     \To be accepted/
#
#
#  ## can =  CC(C)(CC=O)SC
#     \To be accepted/
#
#
#  ## can =  CC(C)(CC(=O)O)SC
#     \To be accepted/
#
#
#  ## can =  CCSC(C)(C)CC=O
#     \To be accepted/
#
#
#  ## can =  CCSC(C)(C)CC(=O)O
#     \To be accepted/
#
#
#  ## can =  CC(C)(CC=O)SCCN
#     \To be accepted/
#
#
#  ## can =  CC1(CNCS1)C
#     \To be accepted/
#
#
#  ## can =  CC1NCC(S1)(C)C
#     \To be accepted/
#
#
#  ## can =  CC1(CN2C(S1)CC2=O)C
#     # found 5-membered aromatic ring
#     \To be accepted/
#
#
#  ## can =  CC1(CNC(S1)CN)C
#     \To be accepted/
#
#
#  ## can =  CC1(CN(CS1)C=O)C
#     # found 5-membered aromatic ring
#     \To be accepted/
#
#
#  ## can =  CCSC(C)(C)C
#     \To be accepted/
#
#
#  ## can =  CC(C)(C)SCCN
#     \To be accepted/
#
#
#  ## can =  CC(C)(C)SCC(C=O)N
#     \To be accepted/
#  ## can =  CC(C)(C)SCCNC=O
#     \To be accepted/
#
#
#  ## can =  CC(C)(C)SCCC=O
#     \To be accepted/
#
#
#  ## can =  CC(C)(C(C=O)N)S
#     \To be accepted/
#
#
#  ## can =  CC(C)(C(C(=O)O)N)S
#     \To be accepted/
#
#
#  ## can =  CC(C)(C(C=O)NC=O)S
#     \To be accepted/
#
#
#  ## can =  CC(C)(CC=O)S
#     \To be accepted/
#
#
#  ## can =  CC(C)(CC(=O)O)S
#     \To be accepted/
#
#
#  ## can =  CC(C)(CNC=O)S
#     \To be accepted/
#
#
#  ## can =  CC(=O)NCC(C)(C)S
#     \To be accepted/
#
#
#  ## can =  CC(C)(CNC(=O)CN)S
#     \To be accepted/
#
#
#  ## can =  CC(C)SC
#     \To be accepted/
#
#
#  ## can =  CC(C)SCN
#     \To be accepted/
#
#
#  ## can =  CCSC(C)C
#     \To be accepted/
#
#
#  ## can =  CC(C)SC(C)N
#     \To be accepted/
#
#
#  ## can =  CC(C)SC(CN)N
#     \To be accepted/
#
#
#  ## can =  CC(C)SC1C(C(=O)N1)N
#     \To be accepted/
#
#
#  ## can =  CC(C)SC(CNC=O)N
#     \To be accepted/
#
#
#  ## can =  CC(C)SC1CC(=O)N1
#     \To be accepted/
#
#
#  ## can =  CC(C)SCCN
#     \To be accepted/
#
#
#  ## can =  CC(C)SCC(C=O)N
#     \To be accepted/
#
#
#  ## can =  CC(C)SCCNC=O
#     \To be accepted/
#
#
#  ## can =  CC(C)SCCNC(=O)C
#     \To be accepted/
#
#
#  ## can =  CC(C)SCCC=O
#     \To be accepted/
#
#
#  ## can =  CC(C)SCNC=O
#     \To be accepted/
#
#
#  ## can =  CC(C)CN
#     \To be accepted/
#
#
#  ## can =  CC(C)C(C=O)N
#     \To be accepted/
#
#
#  ## can =  CC(C)C(C=O)NC
#     \To be accepted/
#
#
#  ## can =  CC(C)C(C(=O)O)N
#     \To be accepted/
#
#
#  ## can =  CC(C)C(C(=O)O)NC
#     \To be accepted/
#
#
#  ## can =  CC(C)C(C(=O)O)NC=O
#     \To be accepted/
#
#
#  ## can =  CCNC(C(C)C)C(=O)O
#     \To be accepted/
#
#
#  ## can =  CC(C)C(C=O)N(C)C=O
#     \To be accepted/
#
#
#  ## can =  CC(C)C(C=O)NC=O
#     \To be accepted/
#
#
#  ## can =  CC(C)C(C=O)NC(=O)C
#     \To be accepted/
#
#
#  ## can =  CCNC(C=O)C(C)C
#     \To be accepted/
#
#
#  ## can =  CC(C)C(C=O)NCCN
#     \To be accepted/
#
#
#  ## can =  CC(C)CC=O
#     \To be accepted/
#
#
#  ## can =  CC(C)CC(=O)O
#     \To be accepted/
#
#
#  ## can =  CC(C)CNC
#     \To be accepted/
#
#
#  ## can =  CC(C)CN(C)C=O
#     \To be accepted/
#
#
#  ## can =  CC(C)CN1CCC1=O
#     \To be accepted/
#
#
#  ## can =  CC(C)CN1CC(C1=O)N
#     \To be accepted/
#
#
#  ## can =  CC(C)CNC=O
#     \To be accepted/
#
#
#  ## can =  CC(C)CNC(=O)C
#     \To be accepted/
#
#
#  ## can =  CC(C)CNC(=O)CN
#     \To be accepted/
#
#
#  ## can =  CCNCC(C)C
#     \To be accepted/
#
#
#  ## can =  CC(C)CNCCN
#     \To be accepted/
#
#
#  ## can =  CC(C)CNCCNC=O
#     \To be accepted/
#
#
#  ## can =  CC(CN)S
#     \To be accepted/
#
#
#  ## can =  CC(C)SC
#     \To be accepted/
#
#
#  ## can =  CC1C(NCS1)C=O
#     \To be accepted/
#
#
#  ## can =  CC1C(NCS1)C(=O)O
#     \To be accepted/
#
#
#  ## can =  CC1C(NC(S1)C)C=O
#     \To be accepted/
#
#
#  ## can =  CC1C(NC(S1)C)C(=O)O
#     \To be accepted/
#
#
#  ## can =  CC1C(NC(S1)CN)C=O
#     \To be accepted/
#
#
#  ## can =  CC1C(N(CS1)C=O)C=O
#     # found 5-membered aromatic ring
#     \To be accepted/
#
#
#  ## can =  CC(CC=O)SC
#     \To be accepted/
#
#
#  ## can =  CC(CC(=O)O)SC
#     \To be accepted/
#
#
#  ## can =  CCSC(C)CC=O
#     \To be accepted/
#
#
#  ## can =  CCSC(C)CC(=O)O
#     \To be accepted/
#
#
#  ## can =  CC(CC(=O)O)SCCN
#     \To be accepted/
#
#
#  ## can =  CC(CC=O)SCCN
#     \To be accepted/
#
#
#  ## can =  CC(CC=O)SCCC=O
#     \To be accepted/
#
#
#  ## can =  CC1CNCS1
#     \To be accepted/
#
#
#  ## can =  CC1CNC(S1)C
#     \To be accepted/
#
#
#  ## can =  CC1CN2C(S1)CC2=O
#     # found 5-membered aromatic ring
#     \To be accepted/
#
#
#  ## can =  CC1CN2C(S1)C(C2=O)N
#     # found 5-membered aromatic ring
#     \To be accepted/
#
#
#  ## can =  CC1CNC(S1)CN
#     \To be accepted/
#
#
#  ## can =  CC1CNC(S1)CNC=O
#     \To be accepted/
#
#
#  ## can =  CC1CN(CS1)C=O
#     # found 5-membered aromatic ring
#     \To be accepted/
#
#
#  ## can =  CCSC(C)C
#     \To be accepted/
#
#
#  ## can =  CC(C)SCCN
#     \To be accepted/
#
#
#  ## can =  CC(C)SCC(C=O)N
#     \To be accepted/
#
#
#  ## can =  CC(C)SCCNC=O
#     \To be accepted/
#
#
#  ## can =  CC(C)SCCNC(=O)C
#     \To be accepted/
#
#
#  ## can =  CC(C)SCCC=O
#     \To be accepted/
#
#
#  ## can =  CC(C(C=O)N)S
#     \To be accepted/
#
#
#  ## can =  CC(C(C(=O)O)N)S
#     \To be accepted/
#
#
#  ## can =  CC(C(C(=O)O)NC=O)S
#     \To be accepted/
#
#
#  ## can =  CC(C(C=O)NC=O)S
#     \To be accepted/
#
#
#  ## can =  CC(C(C=O)NC(=O)C)S
#     \To be accepted/
#
#
#  ## can =  CC(CC=O)S
#     \To be accepted/
#
#
#  ## can =  CC(CC(=O)O)S
#     \To be accepted/
#
#
#  ## can =  CC(CNC=O)S
#     \To be accepted/
#
#
#  ## can =  CC(CNC(=O)C)S
#     \To be accepted/
#
#
#  ## can =  CC(CNC(=O)CN)S
#     \To be accepted/
#
#
#  ## can =  CCSC
#     \To be accepted/
#
#
#  ## can =  CCSCN
#     \To be accepted/
#
#
#  ## can =  CCSCC
#     \To be accepted/
#
#
#  ## can =  CCSC(C)N
#     \To be accepted/
#
#
#  ## can =  CCSC(CN)N
#     \To be accepted/
#
#
#  ## can =  CCSC1C(C(=O)N1)N
#     \To be accepted/
#
#
#  ## can =  CCSC(CNC=O)N
#     \To be accepted/
#
#
#  ## can =  CCSC(CNC(=O)C)N
#     \To be accepted/
#
#
#  ## can =  CCSC1CC(=O)N1
#     \To be accepted/
#
#
#  ## can =  CCSCCN
#     \To be accepted/
#
#
#  ## can =  CCSCC(C=O)N
#     \To be accepted/
#
#
#  ## can =  CCSCC(C=O)NC=O
#     \To be accepted/
#
#
#  ## can =  CCSCCNC=O
#     \To be accepted/
#
#
#  ## can =  CCSCCNC(=O)C
#     \To be accepted/
#
#
#  ## can =  CCSCCC=O
#     \To be accepted/
#
#
#  ## can =  CCSCNC=O
#     \To be accepted/
#
#
#  ## can =  CCCN
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)N
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)NC
#     \To be accepted/
#
#
#  ## can =  CCC(C(=O)O)N
#     \To be accepted/
#
#
#  ## can =  CCC(C(=O)O)NC
#     \To be accepted/
#
#
#  ## can =  CCC(C(=O)O)N(C)C=O
#     \To be accepted/
#
#
#  ## can =  CCC(C(=O)O)NC=O
#     \To be accepted/
#
#
#  ## can =  CCC(C(=O)O)NC(=O)C
#     \To be accepted/
#
#
#  ## can =  CCC(C(=O)O)NCC
#     \To be accepted/
#
#
#  ## can =  CCC(C(=O)O)NCCN
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)N(C)C=O
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)N1CCC1=O
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)NC=O
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)NC(=O)C
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)NC(=O)CN
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)NCC
#     \To be accepted/
#
#
#  ## can =  CCC(C=O)NCCN
#     \To be accepted/
#
#
#  ## can =  CCCC=O
#     \To be accepted/
#
#
#  ## can =  CCCC(=O)O
#     \To be accepted/
#
#
#  ## can =  CCCNC
#     \To be accepted/
#
#
#  ## can =  CCCN(C)C=O
#     \To be accepted/
#
#
#  ## can =  CCCN1CCC1=O
#     \To be accepted/
#
#
#  ## can =  CCCN1CC(C1=O)N
#     \To be accepted/
#
#
#  ## can =  CCCNC=O
#     \To be accepted/
#
#
#  ## can =  CCCNC(=O)C
#     \To be accepted/
#
#
#  ## can =  CCCNC(=O)CN
#     \To be accepted/
#
#
#  ## can =  CCCNC(=O)CNC=O
#     \To be accepted/
#
#
#  ## can =  CCCNCC
#     \To be accepted/
#
#
#  ## can =  CCCNCCN
#     \To be accepted/
#
#
#  ## can =  CCCNCCNC=O
#     \To be accepted/
#
#
#  ## can =  CCCNCCNC(=O)C
#     \To be accepted/
#   ++ found 0 cov amons
# cans= ['C', 'N', 'S', 'O', 'CC', 'CS', 'CN', 'C=O', 'C=C', 'C(=O)O', 'C=CC=C', 'c1ccccc1', 'CC=C', 'CC(=C)C=C', 'Cc1ccccc1', 'CC=CC=C', 'CC=O', 'C=CCC=O', 'C=CC(=C)CC=O', 'c1ccc(cc1)CC=O', 'C=CC=CCC=O', 'C(=O)N', 'CC(=O)N', 'C=CCC(=O)N', 'C=CC(=C)CC(=O)N', 'c1ccc(cc1)CC(=O)N', 'C=CC=CCC(=O)N', 'CNC=O', 'CC(=O)NC', 'CNC(=O)CC=C', 'CNC(=O)CC(=C)C=C', 'CNC(=O)CC=CC=C', 'C(C=O)N', 'C(C=O)NC=O', 'CC(=O)NCC=O', 'C=CCC(=O)NCC=O', 'CCN', 'CC(C=O)N', 'CC(C=O)NC=O', 'CC(C=O)NC(=O)C', 'CC(C=O)NC(=O)CC=C', 'CCNC=O', 'CCNC(=O)C', 'CCNC(=O)CC=C', 'CCNC(=O)CC(=C)C=C', 'CCNC(=O)CC=CC=C', 'CCC=O', 'CCS', 'C(CS)N', 'C(C(C=O)N)S', 'C(C(C=O)NC=O)S', 'CC(=O)NC(CS)C=O', 'C(CS)NC=O', 'CC(=O)NCCS', 'C=CCC(=O)NCCS', 'C(CS)C=O', 'C(C(=O)N)N', 'C(C(=O)N)NC=O', 'CC(=O)NCC(=O)N', 'C=CCC(=O)NCC(=O)N', 'C(N)S', 'CC(N)S', 'C1C(NC1=O)S', 'C1(C(NC1=O)S)N', 'C(=O)NC1C(NC1=O)S', 'CC(=O)NC1C(NC1=O)S', 'C(C(N)S)N', 'C(C(N)S)NC=O', 'CC(=O)NCC(N)S', 'C=CCC(=O)NCC(N)S', 'C1CNC1=O', 'C1C(C(=O)N1)N', 'C1C(C(=O)N1)NC=O', 'CC(=O)NC1CNC1=O', 'C(CN)N', 'C(CNC=O)N', 'CC(=O)NCCN', 'C=CCC(=O)NCCN', 'C(NC=O)S', 'CC(=O)O', 'CNC', 'CN(CC=O)C=O', 'CN(CC(=O)O)C=O', 'C(C=O)N(CS)C=O', 'C(C(=O)O)N(CS)C=O', 'C1CN(C1=O)CC=O', 'C1CN(C1=O)CC(=O
 'CCC(C(=O)O)NC=O', 'CCC(C(=O)O)NC(=O)C', 'CCC(C(=O)O)NCC', 'CCC(C(=O)O)NCCN', 'CCC(C=O)N(C)C=O', 'CCC(C=O)N1CCC1=O', 'CCC(C=O)NC=O', 'CCC(C=O)NC(=O)C', 'CCC(C=O)NC(=O)CN', 'CCC(C=O)NCC', 'CCC(C=O)NCCN', 'C(C(C(=O)O)N)S', 'C1C(NCS1)C=O', 'C1C(NCS1)C(=O)O', 'C1C(N(CS1)C=O)C(=O)O', 'CC1NC(CS1)C(=O)O', 'C1C(NC(S1)CN)C(=O)O', 'C1C(N(CS1)C=O)C=O', 'C1C2N(C1=O)C(CS2)C=O', 'CC1NC(CS1)C=O', 'C1C(NC(S1)CN)C=O', 'C(C(C(=O)O)NC=O)S', 'CC(=O)NC(CS)C(=O)O', 'C(C(C=O)NC(=O)CN)S', 'CC(C=O)NC', 'CC(C(=O)O)N', 'CC(C(=O)O)NC', 'CC(C(=O)O)N(C)C=O', 'CC(C(=O)O)N1CCC1=O', 'CC(C(=O)O)NC=O', 'CC(C(=O)O)NC(=O)C', 'CC(C(=O)O)NC(=O)CN', 'CCNC(C)C(=O)O', 'CC(C(=O)O)NCCN', 'CC(C=O)N(C)C=O', 'CC(C=O)N1CCC1=O', 'CC(C=O)N1CC(C1=O)N', 'CC(C=O)NC(=O)CN', 'CCNC(C)C=O', 'CC(C=O)NCCN', 'CC(C=O)NCCNC=O', 'CC(CC=O)S', 'CC(CC(=O)O)S', 'CC(CC=O)SC', 'CC(CC(=O)O)SC', 'CCSC(C)CC(=O)O', 'CC(CC(=O)O)SCCN', 'CCSC(C)CC=O', 'CC(CC=O)SCCN', 'CC(CC=O)SCCC=O', 'CCCC=O', 'CCCC(=O)O', 'C(CS)C(=O)O', 'CSCCC(=O)O', 'CCSCCC(=O)O', 'C(CSCCN)C(=O)O', 'C(CSCCC(=O)O)C=O', 'C(CSCCN)C=O', 'C(CSCC(C=O)N)C=O', 'C(CSCCNC=O)C=O', 'C(CSCCC=O)C=O', 'CCC(=O)O', 'CC1CNCS1', 'CC1CN(CS1)C=O', 'CC1CN2C(S1)CC2=O', 'CC1CN2C(S1)C(C2=O)N ...
#  -- now sort amon SMILES by N_I
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-9a7f7eb1631e> in <module>
# ----> 1 obj = caa.ParentMols(target, k=10, i3d=False, label='label')
#
# ~/bin/aqml/cheminfo/oechem/amon.py in __init__(self, strings, reduce_namons, fixGeom, iat, wg, i3d, iwa, k, iprt, submol, label, stereo, isotope, iextl, substring, rcut, imap, k2, opr, M, iclean, scale_vdw, thresh, wsmi, keepHalogen, nprocs, forcefield, gopt, ixtb, nocrowd, icc4Rsp3out, nogc, iasp2arout, ioc, iocn, icrl2o, igchk, irddtout, ivdw, ivao, nmaxcomb, reuseg, saveg, irad, ichg, prefix, iwarn, debug, log)
#    1840             if imap:
#    1841                 print(' -- now sort amon SMILES by N_I')
# -> 1842                 seta._sort2()
#    1843                 cans = seta.cans
#    1844                 self.cans = cans
#
# ~/bin/aqml/cheminfo/oechem/amon.py in _sort2(self)
#     503             for j in range(namons[i]):
#     504                 jcan, jc = maps_i[j,:] # `jcan: the old idx of can
# --> 505                 jcan_u = seqs[ seqs_u == jcan ] # new idx of can
#     506                 maps2[i, jcnt] = jcan_u
#     507                 jcnt += 1
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is
CC(C)SCCNC=O', 'CC(C)SCCNC(=O)C', 'CC(C)SCCC=O', 'CC(C)C', 'CC(C)(C)S', 'CC(C)(CN)S', 'CC(C)(C)SC', 'CC1(C(NCS1)C=O)C', 'CC1(C(NCS1)C(=O)O)C', 'CC1NC(C(S1)(C)C)C=O', 'CC(C)(CC=O)SC', 'CC(C)(CC(=O)O)SC', 'CCSC(C)(C)CC=O', 'CCSC(C)(C)CC(=O)O', 'CC(C)(CC=O)SCCN', 'CC1(CNCS1)C', 'CC1NCC(S1)(C)C', 'CC1(CN2C(S1)CC2=O)C', 'CC1(CNC(S1)CN)C', 'CC1(CN(CS1)C=O)C', 'CCSC(C)(C)C', 'CC(C)(C)SCCN', 'CC(C)(C)SCC(C=O)N', 'CC(C)(C)SCCNC=O', 'CC(C)(C)SCCC=O', 'CC(C)(C(C=O)N)S', 'CC(C)(C(C(=O)O)N)S', 'CC(C)(C(C=O)NC=O)S', 'CC(C)(CC=O)S', 'CC(C)(CC(=O)O)S', 'CC(C)(CNC=O)S', 'CC(=O)NCC(C)(C)S', 'CC(C)(CNC(=O)CN)S', 'CC(C)SCN', 'CC(C)SC(C)N', 'CC(C)SC(CN)N', 'CC(C)SC1C(C(=O)N1)N', 'CC(C)SC(CNC=O)N', 'CC(C)SC1CC(=O)N1', 'CC(C)SCNC=O', 'CC(C)CN', 'CC(C)C(C=O)N', 'CC(C)C(C=O)NC', 'CC(C)C(C(=O)O)N', 'CC(C)C(C(=O)O)NC', 'CC(C)C(C(=O)O)NC=O', 'CCNC(C(C)C)C(=O)O', 'CC(C)C(C=O)N(C)C=O', 'CC(C)C(C=O)NC=O', 'CC(C)C(C=O)NC(=O)C', 'CCNC(C=O)C(C)C', 'CC(C)C(C=O)NCCN', 'CC(C)CC=O', 'CC(C)CC(=O)O', 'CC(C)CNC', 'CC(C)CN(C)C=O', 'CC(C)CN1CCC1=O', 'CC(C)CN1CC(C1=O)N', 'CC(C)CNC=O', 'CC(C)CNC(=O)C', 'CC(C)CNC(=O)CN', 'CCNCC(C)C', 'CC(C)CNCCN', 'CC(C)CNCCNC=O']

# %%
import numpy as np
amons = np.unique(cans)

# %%
# !ls
# Out:
# 'Generate penicillin amons.ipynb'   GetSLATMAmons.ipynb
#  GetaCMAmons.ipynb		    GetSLATMGlobalAmons.ipynb
#  GetaCM.ipynb			    GetSLATMGlobal.ipynb
#  GetAdjMatrices.ipynb		    GetSLATM.ipynb
#  GetCMAmons.ipynb		    GetSOAPGlobalAmons.ipynb
#  GetCMGlobalAmons.ipynb		    GetSOAPGlobal.ipynb
#  GetCMGlobal.ipynb		    GetSOAP.ipynb
#  GetCM.ipynb			    label
#  GetFCHLAmons.ipynb		    label.can
#  GetFCHLGlobalAmons.ipynb	    label.out
#  GetFCHLGlobal.ipynb		    label.pkl
#  GetFCHL.ipynb			    xyz2sdf.ipynb

# %%
with open("../amons-penicillin/smiles.txt", "w") as f:
    for smi in cans:
        f.write(smi)
        f.write("\n")
