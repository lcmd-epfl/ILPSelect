# %%
import pandas as pd

# %%
import numpy as np

# %%
# !ls ../out
# Out:
# output_aCM.csv		output_amons_SOAP.csv	output_SLATM.csv
# output_amons_aCM.csv	output_CM_global.csv	output_SLATM_global.csv
# output_amons_FCHL.csv	output_FCHL.csv		output_SOAP.csv
# output_amons_SLATM.csv	output_FCHL_global.csv	output_SPAHM_global.csv

# %%
slatm_out = pd.read_csv("../out/output_SPAHM_global.csv", index_col=0)

# %%
slatm_out
# Out:
#      SolN                                          Fragments  ObjValNoPen  \
# 0       1               ['frag_01_c00001', 'frag_11_c00001']   694.725961
# 1       2               ['frag_01_c00001', 'frag_11_c00001']   694.725961
# 2       3               ['frag_01_c00001', 'frag_11_c00001']   694.725961
# 3       4               ['frag_01_c00001', 'frag_11_c00001']   694.725961
# 4       5               ['frag_01_c00001', 'frag_12_c00001']   695.264597
# ..    ...                                                ...          ...
# 995   996  ['frag_01_c00001', 'frag_06_c00001', 'frag_09_...  1828.977057
# 996   997  ['frag_01_c00001', 'frag_06_c00001', 'frag_09_...  1828.977057
# 997   998               ['frag_12_c00001', 'frag_13_c00001']   848.353227
# 998   999               ['frag_12_c00001', 'frag_13_c00001']   848.353227
# 999  1000               ['frag_12_c00001', 'frag_13_c00001']   848.353227
#
#      ObjValWithPen
# 0       694.725961
# 1       694.725961
# 2       694.725961
# 3       694.725961
# 4       695.264597
# ..             ...
# 995    7828.977057
# 996    7828.977057
# 997    7848.353227
# 998    7848.353227
# 999    7848.353227
#
# [1000 rows x 4 columns]

# %%
from ast import literal_eval

# %%
slatm_out["Fragments"] = slatm_out["Fragments"].apply(literal_eval)

# %%
slatm_out["Sorted Fragments"] = slatm_out["Fragments"].apply(lambda x:sorted(x))

# %%
len(np.unique(slatm_out["Sorted Fragments"]))
# Out:
# 215

# %%
# excess is missing Hs - to fix

# %%
import qml

# %%
qm9_mol = qml.Compound("../targets/qm9_0.xyz")
qm9_ncharges = qm9_mol.nuclear_charges

# %%
qm9_ncharges
# Out:
# array([8, 6, 6, 7, 6, 8, 8, 7, 6, 1, 1])

# %%
def count_ncharges(list_ncharges, elements=[1,6,7,8,16]):
    ncharge_count = np.zeros(len(elements))
    for ncharge in list_ncharges:
        for i, elem in enumerate(elements):
            if ncharge == elem:
                ncharge_count[i] += 1
    return ncharge_count

# %%
qm9_counts = count_ncharges(qm9_ncharges)

# %%
qm9_counts
# Out:
# array([2., 4., 2., 3., 0.])

# %%
def get_excess_frags(frag_list):
    mols = [qml.Compound("../amons-qm9/"+x+".xyz") for x in frag_list]
    ncharges = np.concatenate([mol.nuclear_charges for mol in mols])
    ncharge_count = count_ncharges(ncharges)
    
    diff_count = ncharge_count - qm9_counts
    diff_count = np.array(diff_count).astype(int)
    excess = []
    for i, count in enumerate(diff_count): 
        ncharge = [1,6,7,8,16][i]
        if count > 0 :
            for i in range(count):
                excess.append(ncharge)
        elif count < 0:
            for i in range(abs(count)):
                excess.append(-ncharge)
    return excess

# %%
slatm_out["Excess"] = slatm_out["Fragments"].apply(get_excess_frags)

# %%
slatm_out
# Out:
#      SolN                                         Fragments  ObjValNoPen  \
# 0       1                  [frag_01_c00001, frag_11_c00001]   694.725961
# 1       2                  [frag_01_c00001, frag_11_c00001]   694.725961
# 2       3                  [frag_01_c00001, frag_11_c00001]   694.725961
# 3       4                  [frag_01_c00001, frag_11_c00001]   694.725961
# 4       5                  [frag_01_c00001, frag_12_c00001]   695.264597
# ..    ...                                               ...          ...
# 995   996  [frag_01_c00001, frag_06_c00001, frag_09_c00001]  1828.977057
# 996   997  [frag_01_c00001, frag_06_c00001, frag_09_c00001]  1828.977057
# 997   998                  [frag_12_c00001, frag_13_c00001]   848.353227
# 998   999                  [frag_12_c00001, frag_13_c00001]   848.353227
# 999  1000                  [frag_12_c00001, frag_13_c00001]   848.353227
#
#      ObjValWithPen                                  Sorted Fragments  \
# 0       694.725961                  [frag_01_c00001, frag_11_c00001]
# 1       694.725961                  [frag_01_c00001, frag_11_c00001]
# 2       694.725961                  [frag_01_c00001, frag_11_c00001]
# 3       694.725961                  [frag_01_c00001, frag_11_c00001]
# 4       695.264597                  [frag_01_c00001, frag_12_c00001]
# ..             ...                                               ...
# 995    7828.977057  [frag_01_c00001, frag_06_c00001, frag_09_c00001]
# 996    7828.977057  [frag_01_c00001, frag_06_c00001, frag_09_c00001]
# 997    7848.353227                  [frag_12_c00001, frag_13_c00001]
# 998    7848.353227                  [frag_12_c00001, frag_13_c00001]
# 999    7848.353227                  [frag_12_c00001, frag_13_c00001]
#
#                         Excess
# 0        [1, 1, 1, -6, -6, -7]
# 1        [1, 1, 1, -6, -6, -7]
# 2        [1, 1, 1, -6, -6, -7]
# 3        [1, 1, 1, -6, -6, -7]
# 4        [1, 1, 1, -6, -6, -7]
# ..                         ...
# 995  [1, 1, 1, 1, 1, 1, 1, -7]
# 996  [1, 1, 1, 1, 1, 1, 1, -7]
# 997      [1, 1, 1, 1, 1, 6, 7]
# 998      [1, 1, 1, 1, 1, 6, 7]
# 999      [1, 1, 1, 1, 1, 6, 7]
#
# [1000 rows x 6 columns]

# %%
# get energies
# qm7 energies are in qm7 dir 
# need qm9 energies and excess contribution

# %%
from sklearn.linear_model import LinearRegression

# %%
# need ncharges list and list of energies

# %%
import qml

# %%
qm7 = pd.read_csv("../qm7/energies.csv", index_col=0)
files = qm7["file"].to_list()

# %%
mols = [qml.Compound("../qm7/xyz/"+x+".xyz") for x in files]

# %%
ncharges = [mol.nuclear_charges for mol in mols]

# %%
# ncharges convert to count
elements = [1, 6, 7, 8, 16]
ncharge_counts = []
for ncharge_list in ncharges: 
    ncharge_count = count_ncharges(ncharge_list)
    ncharge_counts.append(ncharge_count)

# %%
energies = qm7["energy / Ha"].to_list()

# %%
reg = LinearRegression().fit(ncharge_counts, energies)

# %%
reg.score(ncharge_counts, energies)
# Out:
# 0.9999998316921461

# %%
coeff_energies = reg.coef_

# %%
coeff_energies = dict(zip(elements, coeff_energies))

# %%
coeff_energies
# Out:
# {1: -0.610028423353568,
#  6: -38.01906466911171,
#  7: -54.647732784759256,
#  8: -75.09076868694648,
#  16: -397.9423885459585}

# %%
def match_file_to_energy(filename):
    energies = pd.read_csv("../amons-qm9/energies.csv")
    energy = energies.loc[energies["file"] == filename]["energy / Ha"]
    energy = float(energy)
    return energy

# %%
def get_excess_energy(excess_ncharges):
    energy = 0.
    for ncharge in excess_ncharges:
        if ncharge < 0:
            ncharge = abs(ncharge)
            energy += -1 * coeff_energies[ncharge]
        else:
            energy += coeff_energies[ncharge]
    return energy

# %%
def get_reaction_energy(fragment_list, excess_ncharges):
    qm9_energy = -487.817450280942 # Ha
    
    excess_energy = get_excess_energy(excess_ncharges)
    
    frag_energies = np.sum([match_file_to_energy(x) for x in fragment_list])
    
    rxn_energy = frag_energies - qm9_energy - excess_energy
    return rxn_energy

# %%
slatm_out["energies / Ha"] = slatm_out.apply(lambda x: get_reaction_energy(x["Fragments"], x["Excess"]),
                                                     axis=1)

# %%
slatm_out["energies / kcal/mol"] = slatm_out["energies / Ha"] * 627.5

# %%
slatm_out.iloc[0:30]
# Out:
#     SolN                         Fragments  ObjValNoPen  ObjValWithPen  \
# 0      1  [frag_01_c00001, frag_11_c00001]   694.725961     694.725961
# 1      2  [frag_01_c00001, frag_11_c00001]   694.725961     694.725961
# 2      3  [frag_01_c00001, frag_11_c00001]   694.725961     694.725961
# 3      4  [frag_01_c00001, frag_11_c00001]   694.725961     694.725961
# 4      5  [frag_01_c00001, frag_12_c00001]   695.264597     695.264597
# 5      6  [frag_01_c00001, frag_12_c00001]   695.264597     695.264597
# 6      7  [frag_01_c00001, frag_12_c00001]   695.264597     695.264597
# 7      8  [frag_01_c00001, frag_12_c00001]   695.264597     695.264597
# 8      9  [frag_01_c00001, frag_07_c00001]   774.601428     774.601428
# 9     10  [frag_01_c00001, frag_07_c00001]   774.601428     774.601428
# 10    11  [frag_01_c00001, frag_07_c00001]   774.601428     774.601428
# 11    12  [frag_01_c00001, frag_07_c00001]   774.601428     774.601428
# 12    13  [frag_02_c00001, frag_05_c00001]   886.792447     886.792447
# 13    14  [frag_02_c00001, frag_05_c00001]   886.792447     886.792447
# 14    15  [frag_02_c00001, frag_05_c00001]   886.792447     886.792447
# 15    16  [frag_02_c00001, frag_05_c00001]   886.792447     886.792447
# 16    17  [frag_04_c00001, frag_10_c00001]   907.695790     907.695790
# 17    18  [frag_04_c00001, frag_10_c00001]   907.695790     907.695790
# 18    19  [frag_04_c00001, frag_10_c00001]   907.695790     907.695790
# 19    20  [frag_04_c00001, frag_10_c00001]   907.695790     907.695790
# 20    21  [frag_04_c00001, frag_08_c00001]   908.464212     908.464212
# 21    22  [frag_04_c00001, frag_08_c00001]   908.464212     908.464212
# 22    23  [frag_04_c00001, frag_08_c00001]   908.464212     908.464212
# 23    24  [frag_04_c00001, frag_08_c00001]   908.464212     908.464212
# 24    25  [frag_03_c00001, frag_06_c00001]   913.881057     913.881057
# 25    26  [frag_03_c00001, frag_06_c00001]   913.881057     913.881057
# 26    27  [frag_03_c00001, frag_06_c00001]   913.881057     913.881057
# 27    28  [frag_03_c00001, frag_06_c00001]   913.881057     913.881057
# 28    29  [frag_01_c00001, frag_09_c00001]   973.359549     973.359549
# 29    30  [frag_01_c00001, frag_09_c00001]   973.359549     973.359549
#
#                     Sorted Fragments                        Excess  \
# 0   [frag_01_c00001, frag_11_c00001]         [1, 1, 1, -6, -6, -7]
# 1   [frag_01_c00001, frag_11_c00001]         [1, 1, 1, -6, -6, -7]
# 2   [frag_01_c00001, frag_11_c00001]         [1, 1, 1, -6, -6, -7]
# 3   [frag_01_c00001, frag_11_c00001]         [1, 1, 1, -6, -6, -7]
# 4   [frag_01_c00001, frag_12_c00001]         [1, 1, 1, -6, -6, -7]
# 5   [frag_01_c00001, frag_12_c00001]         [1, 1, 1, -6, -6, -7]
# 6   [frag_01_c00001, frag_12_c00001]         [1, 1, 1, -6, -6, -7]
# 7   [frag_01_c00001, frag_12_c00001]         [1, 1, 1, -6, -6, -7]
# 8   [frag_01_c00001, frag_07_c00001]  [1, 1, 1, 1, -6, -6, -8, -8]
# 9   [frag_01_c00001, frag_07_c00001]  [1, 1, 1, 1, -6, -6, -8, -8]
# 10  [frag_01_c00001, frag_07_c00001]  [1, 1, 1, 1, -6, -6, -8, -8]
# 11  [frag_01_c00001, frag_07_c00001]  [1, 1, 1, 1, -6, -6, -8, -8]
# 12  [frag_02_c00001, frag_05_c00001]  [1, 1, 1, 1, -6, -7, -7, -8]
# 13  [frag_02_c00001, frag_05_c00001]  [1, 1, 1, 1, -6, -7, -7, -8]
# 14  [frag_02_c00001, frag_05_c00001]  [1, 1, 1, 1, -6, -7, -7, -8]
# 15  [frag_02_c00001, frag_05_c00001]  [1, 1, 1, 1, -6, -7, -7, -8]
# 16  [frag_04_c00001, frag_10_c00001]         [1, 1, 1, -6, -7, -8]
# 17  [frag_04_c00001, frag_10_c00001]         [1, 1, 1, -6, -7, -8]
# 18  [frag_04_c00001, frag_10_c00001]         [1, 1, 1, -6, -7, -8]
# 19  [frag_04_c00001, frag_10_c00001]         [1, 1, 1, -6, -7, -8]
# 20  [frag_04_c00001, frag_08_c00001]         [1, 1, 1, -6, -7, -8]
# 21  [frag_04_c00001, frag_08_c00001]         [1, 1, 1, -6, -7, -8]
# 22  [frag_04_c00001, frag_08_c00001]         [1, 1, 1, -6, -7, -8]
# 23  [frag_04_c00001, frag_08_c00001]         [1, 1, 1, -6, -7, -8]
# 24  [frag_03_c00001, frag_06_c00001]  [1, 1, 1, 1, -6, -6, -8, -8]
# 25  [frag_03_c00001, frag_06_c00001]  [1, 1, 1, 1, -6, -6, -8, -8]
# 26  [frag_03_c00001, frag_06_c00001]  [1, 1, 1, 1, -6, -6, -8, -8]
# 27  [frag_03_c00001, frag_06_c00001]  [1, 1, 1, 1, -6, -6, -8, -8]
# 28  [frag_01_c00001, frag_09_c00001]  [1, 1, 1, 1, -6, -7, -7, -8]
# 29  [frag_01_c00001, frag_09_c00001]  [1, 1, 1, 1, -6, -7, -7, -8]
#
#     energies / Ha  energies / kcal/mol
# 0        0.000741             0.465171
# 1        0.000741             0.465171
# 2        0.000741             0.465171
# 3        0.000741             0.465171
# 4        0.063224            39.673275
# 5        0.063224            39.673275
# 6        0.063224            39.673275
# 7        0.063224            39.673275
# 8        0.050694            31.810765
# 9        0.050694            31.810765
# 10       0.050694            31.810765
# 11       0.050694            31.810765
# 12       0.017757            11.142290
# 13       0.017757            11.142290
# 14       0.017757            11.142290
# 15       0.017757            11.142290
# 16       0.046824            29.382229
# 17       0.046824            29.382229
# 18       0.046824            29.382229
# 19       0.046824            29.382229
# 20       0.046141            28.953746
# 21       0.046141            28.953746
# 22       0.046141            28.953746
# 23       0.046141            28.953746
# 24       0.103127            64.712035
# 25       0.103127            64.712035
# 26       0.103127            64.712035
# 27       0.103127            64.712035
# 28       0.031319            19.652691
# 29       0.031319            19.652691

# %%
import matplotlib.pyplot as plt
import matplotlib

# %%
matplotlib.rcParams.update({'font.size': 12})

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)
ax[0].scatter(np.sqrt(slatm_out["ObjValNoPen"]), slatm_out["energies / kcal/mol"], s=10)
ax[0].set_xlabel("Sum of atom-wise L2-norm")
ax[0].set_ylabel("Reaction energy / kcal/mol")

x = np.exp(-slatm_out["ObjValNoPen"]/(2*100**2))
ax[1].scatter(x, slatm_out["energies / kcal/mol"], s=10)
ax[1].set_xlabel("Similarity")

plt.tight_layout()
plt.savefig("../figures/correlation-amons-spahm-global.png", dpi=300)
plt.show()
